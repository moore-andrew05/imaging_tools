# %%
from KeemPlot import *

# %%
path = "/Volumes/BIG_DATA/04_DATA/04_LIVE_BACTERIAL_IMAGING_ANALYSIS/bactoquant/REP2/"

# %%
dir1 = KeemPlot(path + "JUB66_RFP/", 1, 65535, 0, 3500)
dir2 = KeemPlot(path + "JUB66_RFP_IN_CEMBIO/", 2, 65535, 0, 3500)
dir3 = KeemPlot(path + "MK_JUB66_RFP_IN_JUB66/", 1,  65535, 0, 3500)

# %%
dir1.plot_barcodes(dir1.barcodes, "./figs/rep3_JUB66_RFP.svg")

# %%
dir2.plot_barcodes(dir2.barcodes, "./figs/rep3_JUB66_RFP_IN_CEMBIO.svg")

# %%
dir3.plot_barcodes(dir3.barcodes, "./figs/rep3_MK_JUB66_RFP_IN_JUB66.svg")
