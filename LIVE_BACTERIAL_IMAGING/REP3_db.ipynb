# %%
from KeemPlot import *

# %%
path = "/Volumes/BIG_DATA/04_DATA/04_LIVE_BACTERIAL_IMAGING_ANALYSIS/bactoquant/REP3/"
dir1 = KeemPlot(path + "JUB66_RFP/", 1, 65535, 0, 3500)
dir2 = KeemPlot(path + "JUB66_RFP_IN_CEMBIO", 2, 65535, 0, 3500)
dir3 = KeemPlot(path + "MK_JUB66_RFP_IN_JUB66", 1, 65535, 0, 3500)

# %%
dir1.generate_db()
dir2.generate_db()
dir3.generate_db()

# %%
dir1.update_db("/Users/amoore/projects/stable_txts/IMDB.pkl")
dir2.update_db("/Users/amoore/projects/stable_txts/IMDB.pkl")
dir3.update_db("/Users/amoore/projects/stable_txts/IMDB.pkl")

# %%
dir1.update_db("/Volumes/onishlab_shared/PROJECTS/30_Andrew/03_IMAGING_DATABASE/IMDB.pkl")
dir2.update_db("/Volumes/onishlab_shared/PROJECTS/30_Andrew/03_IMAGING_DATABASE/IMDB.pkl")
dir3.update_db("/Volumes/onishlab_shared/PROJECTS/30_Andrew/03_IMAGING_DATABASE/IMDB.pkl")

# %%
tmp = pd.read_pickle("/Users/amoore/projects/stable_txts/IMDB.pkl")

# %%
tmp
# Out:
#       date strain                   feed temp     name stage rating  \
# 0   230614     N2              JUB66_RFP   25   image1   YL4      4
# 1   230614     N2              JUB66_RFP   25   image2   YL4      4
# 2   230614     N2              JUB66_RFP   25   image3   YL4      5
# 3   230614     N2              JUB66_RFP   25   image4   YL4      4
# 4   230614     N2              JUB66_RFP   25   image5   YL4      4
# ..     ...    ...                    ...  ...      ...   ...    ...
# 85  230721     N2  MK_JUB66_RFP_IN_JUB66   25   image6    L4      4
# 86  230721     N2  MK_JUB66_RFP_IN_JUB66   25   image7   YL4      4
# 87  230721     N2  MK_JUB66_RFP_IN_JUB66   25   image8    L4      3
# 88  230721     N2  MK_JUB66_RFP_IN_JUB66   25   image9    L4      4
# 89  230721     N2  MK_JUB66_RFP_IN_JUB66   25  image10    L4      3
#
#                                              comments     ID  \
# 0                                            comments  00021
# 1                                            comments  00022
# 2                                            comments  00023
# 3                                            comments  00024
# 4    Lots of signal in this one all concentrated n...  00025
# ..                                                ...    ...
# 85                                           comments  00106
# 86                                           comments  00107
# 87                                           comments  00108
# 88                                           comments  00109
# 89                                           comments  00110
#
#                                            array_vals  \
# 0   [0.011764705882352941, 0.011764705882352941, 0...
# 1   [0.010910200656137941, 0.01151731697290573, 0....
# 2   [0.011764705882352941, 0.011764705882352941, 0...
# 3   [0.011444266422522316, 0.011697760685114819, 0...
# 4   [0.011764705882352941, 0.014485120414898868, 0...
# ..                                                ...
# 85  [0.011764705882352941, 0.011764705882352941, 0...
# 86  [0.011764705882352941, 0.011764705882352941, 0...
# 87  [0.011764705882352941, 0.011764705882352941, 0...
# 88  [0.011764705882352941, 0.011764705882352941, 0...
# 89  [0.011764705882352941, 0.011764705882352941, 0...
#
#                                         array_vals_ni
# 0   [0.011764705882352941, 0.011764705882352941, 0...
# 1   [0.010910200656137941, 0.011764705882352941, 0...
# 2   [0.011764705882352941, 0.011764705882352941, 0...
# 3   [0.011444266422522316, 0.011764705882352941, 0...
# 4   [0.011764705882352941, 0.015030136568245976, 0...
# ..                                                ...
# 85  [0.011764705882352941, 0.011764705882352941, 0...
# 86  [0.011764705882352941, 0.011764705882352941, 0...
# 87  [0.011764705882352941, 0.011764705882352941, 0...
# 88  [0.011764705882352941, 0.011764705882352941, 0...
# 89  [0.011764705882352941, 0.011764705882352941, 0...
#
# [90 rows x 11 columns]

# %%
tmp = pd.read_pickle("/Volumes/onishlab_shared/PROJECTS/30_Andrew/03_IMAGING_DATABASE/IMDB.pkl")

# %%
tmp
# Out:
#       date strain                   feed temp     name stage rating  \
# 0   230614     N2              JUB66_RFP   25   image1   YL4      4
# 1   230614     N2              JUB66_RFP   25   image2   YL4      4
# 2   230614     N2              JUB66_RFP   25   image3   YL4      5
# 3   230614     N2              JUB66_RFP   25   image4   YL4      4
# 4   230614     N2              JUB66_RFP   25   image5   YL4      4
# ..     ...    ...                    ...  ...      ...   ...    ...
# 85  230721     N2  MK_JUB66_RFP_IN_JUB66   25   image6    L4      4
# 86  230721     N2  MK_JUB66_RFP_IN_JUB66   25   image7   YL4      4
# 87  230721     N2  MK_JUB66_RFP_IN_JUB66   25   image8    L4      3
# 88  230721     N2  MK_JUB66_RFP_IN_JUB66   25   image9    L4      4
# 89  230721     N2  MK_JUB66_RFP_IN_JUB66   25  image10    L4      3
#
#                                              comments     ID  \
# 0                                            comments  00021
# 1                                            comments  00022
# 2                                            comments  00023
# 3                                            comments  00024
# 4    Lots of signal in this one all concentrated n...  00025
# ..                                                ...    ...
# 85                                           comments  00106
# 86                                           comments  00107
# 87                                           comments  00108
# 88                                           comments  00109
# 89                                           comments  00110
#
#                                            array_vals  \
# 0   [0.011764705882352941, 0.011764705882352941, 0...
# 1   [0.010910200656137941, 0.01151731697290573, 0....
# 2   [0.011764705882352941, 0.011764705882352941, 0...
# 3   [0.011444266422522316, 0.011697760685114819, 0...
# 4   [0.011764705882352941, 0.014485120414898868, 0...
# ..                                                ...
# 85  [0.011764705882352941, 0.011764705882352941, 0...
# 86  [0.011764705882352941, 0.011764705882352941, 0...
# 87  [0.011764705882352941, 0.011764705882352941, 0...
# 88  [0.011764705882352941, 0.011764705882352941, 0...
# 89  [0.011764705882352941, 0.011764705882352941, 0...
#
#                                         array_vals_ni  REP
# 0   [0.011764705882352941, 0.011764705882352941, 0...    1
# 1   [0.010910200656137941, 0.011764705882352941, 0...    1
# 2   [0.011764705882352941, 0.011764705882352941, 0...    1
# 3   [0.011444266422522316, 0.011764705882352941, 0...    1
# 4   [0.011764705882352941, 0.015030136568245976, 0...    1
# ..                                                ...  ...
# 85  [0.011764705882352941, 0.011764705882352941, 0...    3
# 86  [0.011764705882352941, 0.011764705882352941, 0...    3
# 87  [0.011764705882352941, 0.011764705882352941, 0...    3
# 88  [0.011764705882352941, 0.011764705882352941, 0...    3
# 89  [0.011764705882352941, 0.011764705882352941, 0...    3
#
# [90 rows x 12 columns]

# %%
data = tmp["array_vals"].values

# %%
np.random.shuffle(data)

# %%
data.shape
# Out:
# (90,)

# %%
codes = [dir1.create_barcode(arr) for arr in data]

# %%
dir1.plot_barcodes(codes[0:30], save="./figs/aesthetic1.svg")

# %%
dir1.plot_barcodes(codes[30:60], save="./figs/aesthetic2.svg")

# %%
dir1.plot_barcodes(codes[60:90], save="./figs/aesthetic3.svg")
